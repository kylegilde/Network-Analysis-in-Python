# %% [markdown]
# # CUNY D620 - Web Analytics

# %% [markdown]
# ## HW1 - Hello, Graph World!

# %% [markdown]
# ### Kyle Gilde

# %% [markdown]
# The following graphs were generated from NetworkX functions.

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Random Lobster Graph

# %%
G = nx.random_lobster(25, .5, .5, 1)
nx.draw(G)

# %% [markdown]
# #### 2. House Graph

# %%
G = nx.house_graph()
nx.draw(G)

# %% [markdown]
# #### 3. Sedgewick Maze Graph

# %%
G = nx.sedgewick_maze_graph()
nx.draw(G)

# %% [markdown]
# #### 4. Randon Regular Graph

# %%
G = nx.random_regular_graph(45, 60, 1)
nx.draw(G)
